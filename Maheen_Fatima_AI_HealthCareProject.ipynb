# %%
import pandas as pd
import numpy as np
import matplotlib as plot

# %%
dataset= pd.read_excel('/content/Health_Care_data_for_ai_trial.xlsx')

# %%
dataset.head(5)
# Out:
#          MRN  case 1   age  gender    BMI                  DOA   DM  Htn  CAD  \
# 0  920638442        1   57     1.0  24.30  2020-04-08 00:00:00  1.0  0.0  0.0
# 1  106651722        1   38     1.0  25.16  2020-04-12 00:00:00  0.0  0.0  0.0
# 2  920664142        1   47     1.0  30.80  2020-04-14 00:00:00  0.0  0.0  0.0
# 3  920380326        1   24     1.0  23.40  2020-04-16 00:00:00  0.0  0.0  0.0
# 4  920675112        1   55     1.0  31.20  2020-04-21 00:00:00  1.0  0.0  0.0
#
#    prior lung  ...  no days 02  days on HF 02 no BIPAP  days vent  Trach day  \
# 0         0.0  ...         3.0            0.0      0.0         19        NaN
# 1         0.0  ...         1.0            0.0      0.0         55       37.0
# 2         0.0  ...         0.0            0.0      0.0         14        NaN
# 3         0.0  ...         0.0            0.0      0.0        112        NaN
# 4         0.0  ...         2.0            4.0      0.0         23        NaN
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 50 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MRN               376 non-null    int64
#  1   case 1            376 non-null    int64
#  2   age               376 non-null    int64
#  3   gender            375 non-null    float64
#  4   BMI               353 non-null    float64
#  5   DOA               376 non-null    object
#  6   DM                375 non-null    float64
#  7   Htn               372 non-null    float64
#  8   CAD               374 non-null    float64
#  9   prior lung        374 non-null    float64
#  10  COPD              374 non-null    float64
#  11  immune sup        374 non-null    float64
#  12  smokers           329 non-null    object
#  13  alcohol           319 non-null    float64
#  14  02 on adm         353 non-null    float64
#  15  NRB mask          374 non-null    float64
# ...

# %%
dataset.describe()
# Out:
#                 MRN     case 1          age      gender         BMI  \
# count  3.760000e+02  376.000000  376.000000  375.000000  353.000000
# mean   7.537043e+08    0.500000   52.534574    0.770667   30.398527
# std    5.680574e+08    0.500666   13.943271    0.420966    8.518220
# min    1.140540e+06    0.000000   21.000000    0.000000   17.930000
# 25%    9.203055e+08    0.000000   43.000000    1.000000   25.400000
# 50%    9.207118e+08    0.500000   51.000000    1.000000   28.500000
# 75%    9.213305e+08    1.000000   62.000000    1.000000   33.310000
# max    9.211137e+09    1.000000   92.000000    1.000000  100.000000
#
#                DM         Htn         CAD  prior lung        COPD  ...  \
# count  375.000000  372.000000  374.000000  374.000000  374.000000  ...
# mean     0.496000    0.389785    0.093583    0.034759    0.045455  ...
# std      0.500652    0.488358    0.291638    0.183415    0.208578  ...
# ...

# %%
dataset.died.value_counts().plot(kind="bar", color=["salmon", "lightblue"])
# Out:
# <Axes: >

# %%
dataset.fillna(0)
# Out:
#            MRN  case 1   age  gender     BMI                  DOA   DM  Htn  \
# 0    920638442        1   57     1.0   24.30  2020-04-08 00:00:00  1.0  0.0
# 1    106651722        1   38     1.0   25.16  2020-04-12 00:00:00  0.0  0.0
# 2    920664142        1   47     1.0   30.80  2020-04-14 00:00:00  0.0  0.0
# 3    920380326        1   24     1.0   23.40  2020-04-16 00:00:00  0.0  0.0
# 4    920675112        1   55     1.0   31.20  2020-04-21 00:00:00  1.0  0.0
# ..         ...      ...  ...     ...     ...                  ...  ...  ...
# 371   67264999        0   61     1.0   29.70  2020-05-08 00:00:00  0.0  0.0
# 372  920669905        0   41     1.0   34.00  2020-05-08 00:00:00  1.0  0.0
# 373  920577936        0   77     0.0   33.30  2020-05-09 00:00:00  0.0  0.0
# 374  920673967        0   53     1.0   32.00  2020-05-09 00:00:00  0.0  0.0
# 375   41276639        0   50     1.0  100.00  2020-05-09 00:00:00  1.0  0.0
#
# ...

# %%
import seaborn as seab
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(20,20))
#plotting the heatmap for correlation
axises = seab.heatmap(dataset.corr(),annot=True , color ='Purple')
# Out:
# <ipython-input-10-c28e53d87d47>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   axises = seab.heatmap(dataset.corr(),annot=True , color ='Purple')

# %%
import pandas as pd

# Assuming your data is stored in a DataFrame called 'data'
# Replace 'data' with the actual variable name containing your dataset

# Select the relevant columns for analysis
features = ['age', 'gender', 'BMI', 'DM', 'Htn', 'CAD', 'prior lung', 'COPD', 'immune sup', 'smokers', 'alcohol']
target_variables = ['died', 'LOSICU', 'LOSH']

# Compute the correlation matrix
correlation_matrix = dataset[features + target_variables].corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                  age    gender       BMI        DM       Htn       CAD  \
# age         1.000000 -0.026031  0.024058  0.242545  0.378546  0.230595
# gender     -0.026031  1.000000 -0.124074  0.032282 -0.023384  0.045179
# BMI         0.024058 -0.124074  1.000000  0.044704  0.027952  0.037222
# DM          0.242545  0.032282  0.044704  1.000000  0.405420  0.234186
# Htn         0.378546 -0.023384  0.027952  0.405420  1.000000  0.255522
# CAD         0.230595  0.045179  0.037222  0.234186  0.255522  1.000000
# prior lung -0.041055 -0.036156 -0.028156  0.016147  0.028316 -0.011187
# COPD        0.057618 -0.036053  0.063426 -0.009926  0.090922 -0.026431
# immune sup  0.227311 -0.066284 -0.066058  0.085337  0.137793 -0.009241
# alcohol     0.017212  0.056248  0.040502 -0.070943 -0.023338  0.003489
# died        0.248414 -0.016594  0.033319  0.049546  0.161015  0.117250
# LOSICU      0.057644 -0.120018  0.082050  0.040743  0.043692 -0.051008
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your data is stored in a DataFrame called 'data'
# Replace 'data' with the actual variable name containing your dataset

# Select the variables for EDA
variables = ['age', 'gender', 'BMI', 'DM', 'Htn', 'CAD', 'prior lung', 'COPD', 'immune sup', 'smokers', 'alcohol', 'died', 'LOSICU', 'LOSH']

# Create a subset of the data with selected variables
subset_data = dataset[variables].copy()

# Calculate pairwise correlations between variables
correlation_matrix = subset_data.corr()

# Plot correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-12-54a576cae401>:15: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = subset_data.corr()

# %%
(dataset.drop('died', axis=1)
   .corrwith(dataset.died)
   .sort_values(ascending=False)
   .plot(kind='bar', figsize=(12, 4), title="Relation between Features and target variable", alpha=0.1, zorder=4)
   .spines[['top','right', 'left']].set_visible(False)
   )
plt.grid(axis='y', linestyle='--', alpha=.5)
plt.xticks(rotation = 45, ha='right', size=10);
# Out:
# <ipython-input-13-2bf568c7cfa7>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   .corrwith(dataset.died)

# %%
(dataset.drop('LOSH', axis=1)
   .corrwith(dataset.LOSH)
   .sort_values(ascending=False)
   .plot(kind='bar', figsize=(12, 4), title="Relation between Features and target variable", alpha=0.1, zorder=4)
   .spines[['top','right', 'left']].set_visible(False)
   )
plt.grid(axis='y', linestyle='--', alpha=.5)
plt.xticks(rotation = 45, ha='right', size=10);
# Out:
# <ipython-input-14-91dcd1bdbb2a>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   .corrwith(dataset.LOSH)

# %%
(dataset.drop('LOSICU', axis=1)
   .corrwith(dataset.LOSH)
   .sort_values(ascending=False)
   .plot(kind='bar', figsize=(12, 4), title="Relation between Features and target variable", alpha=0.1, zorder=4)
   .spines[['top','right', 'left']].set_visible(False)
   )
plt.grid(axis='y', linestyle='--', alpha=.5)
plt.xticks(rotation = 45, ha='right', size=10);
# Out:
# <ipython-input-15-be85a91c7ee5>:2: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   .corrwith(dataset.LOSH)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

# %%
dataset['smokers'] = dataset['smokers'].replace(['U'], '0')

# %%
dataset = dataset.drop(['DOA'],axis=1)

# %%
dataset = dataset.dropna()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, r2_score

# %%
features = dataset.drop(['LOSH','LOSICU','died'],axis=1)
target_class = dataset['died']
target_regression1 = dataset['LOSICU']
target_regression2 = dataset['LOSH']

# %%
X_encoded = pd.get_dummies(features, drop_first=True)
X_train, X_test, y_class_train, y_class_test, y_reg1_train, y_reg1_test, y_reg2_train, y_reg2_test = train_test_split(
    X_encoded, target_class, target_regression1, target_regression2, test_size=0.2, random_state=42
)
# Out:
# <ipython-input-22-c8e3e7518f2c>:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   X_encoded = pd.get_dummies(features, drop_first=True)

# %%
scaler = StandardScaler()
X_train_reg = scaler.fit_transform(X_train)
X_test_reg = scaler.transform(X_test)

# %%
classifiers = [
    LogisticRegression(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    SVC(),
    GaussianNB(),
    MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500)
]

# %%
for classifier in classifiers:
    classifier.fit(X_train, y_class_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_class_test, y_pred)
    print(f'{classifier.__class__.__name__} - Accuracy: {accuracy:.4f}')
# Out:
# LogisticRegression - Accuracy: 0.8667
# RandomForestClassifier - Accuracy: 0.8667
# GradientBoostingClassifier - Accuracy: 0.8000
# SVC - Accuracy: 0.8667
# GaussianNB - Accuracy: 0.1333
# MLPClassifier - Accuracy: 0.8667

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_score(clf, X_train, Y_train, X_test, Y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(Y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(Y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(Y_train, pred)}\n")

    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(Y_test, pred, output_dict=True))
        print("Test Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(Y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(Y_test, pred)}\n")

# %%
for classifier in classifiers:
 print_score(classifier, X_train, y_class_train, X_test, y_class_test, train=True)
 print_score(classifier, X_train, y_class_train, X_test, y_class_test, train=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
regressors = [
    LinearRegression(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor(),
    SVR(),
    MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=500)
]

# %%
for regressor in regressors:
    regressor.fit(X_train_reg, y_reg1_train)
    y_pred_reg1 = regressor.predict(X_test_reg)
    mse = mean_squared_error(y_reg1_test, y_pred_reg1)
    mae = mean_absolute_error(y_reg1_test, y_pred_reg1)
    r2 = r2_score(y_reg1_test, y_pred_reg1)
    print(f'{regressor.__class__.__name__} - MSE: {mse:.4f}, MAE: {mae:.4f}, R-squared: {r2:.4f}')
# Out:
# LinearRegression - MSE: 245.0473, MAE: 8.7293, R-squared: 0.9097
# DecisionTreeRegressor - MSE: 1091.0000, MAE: 15.5333, R-squared: 0.5980
# RandomForestRegressor - MSE: 969.0969, MAE: 14.9847, R-squared: 0.6429
# GradientBoostingRegressor - MSE: 831.6786, MAE: 13.4077, R-squared: 0.6936
# SVR - MSE: 3355.8815, MAE: 33.2516, R-squared: -0.2365
# MLPRegressor - MSE: 2635.2700, MAE: 30.4127, R-squared: 0.0290
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
regressor.fit(X_train_reg, y_reg2_train)
y_pred_reg2 = regressor.predict(X_test_reg)
mse = mean_squared_error(y_reg2_test, y_pred_reg2)
mae = mean_absolute_error(y_reg2_test, y_pred_reg2)
r2 = r2_score(y_reg2_test, y_pred_reg2)
print(f'{regressor.__class__.__name__} (for target LOSH) - MSE: {mse:.4f}, MAE: {mae:.4f}, R-squared: {r2:.4f}')
# Out:
# MLPRegressor (for target LOSH) - MSE: 3518.7338, MAE: 32.9856, R-squared: -0.3162
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import os

output_dir = 'saved_models'
os.makedirs(output_dir, exist_ok=True)

# %%
import joblib

# %%
classifiers = [
    LogisticRegression(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    SVC(),
    GaussianNB(),
    MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=500)
]

for i, classifier in enumerate(classifiers):
    classifier.fit(X_train, y_class_train)
    y_pred = classifier.predict(X_test)
    accuracy = accuracy_score(y_class_test, y_pred)
    print(f'{classifier.__class__.__name__} - Accuracy: {accuracy:.4f}')

    output_file = os.path.join(output_dir, f'classifier_model_{i}.joblib')
    joblib.dump(classifier, output_file)
# Out:
# LogisticRegression - Accuracy: 0.8667
# RandomForestClassifier - Accuracy: 0.8667
# GradientBoostingClassifier - Accuracy: 0.8000
# SVC - Accuracy: 0.8667
# GaussianNB - Accuracy: 0.1333
# MLPClassifier - Accuracy: 0.8667

# %%
regressors = [
    LinearRegression(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    GradientBoostingRegressor(),
    SVR(),
    MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=500)
]

for i, regressor in enumerate(regressors):
    regressor.fit(X_train_reg, y_reg1_train)
    y_pred_reg1 = regressor.predict(X_test_reg)
    mse = mean_squared_error(y_reg1_test, y_pred_reg1)
    mae = mean_absolute_error(y_reg1_test, y_pred_reg1)
    r2 = r2_score(y_reg1_test, y_pred_reg1)
    print(f'{regressor.__class__.__name__} - MSE: {mse:.4f}, MAE: {mae:.4f}, R-squared: {r2:.4f}')

    output_file = os.path.join(output_dir, f'regression_model{i}.joblib')
    joblib.dump(regressor, output_file)
# Out:
# LinearRegression - MSE: 245.0473, MAE: 8.7293, R-squared: 0.9097
# DecisionTreeRegressor - MSE: 1100.8667, MAE: 15.8000, R-squared: 0.5944
# RandomForestRegressor - MSE: 991.7553, MAE: 15.4773, R-squared: 0.6346
# GradientBoostingRegressor - MSE: 764.4800, MAE: 13.6550, R-squared: 0.7183
# SVR - MSE: 3355.8815, MAE: 33.2516, R-squared: -0.2365
# MLPRegressor - MSE: 3845.8848, MAE: 32.8952, R-squared: -0.4170
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
